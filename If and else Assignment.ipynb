# %%
#QUESTION 1 :- Write a program to calculate the electricity bill
#using only if statement? (accept number of unit from user)


units = int(input("enter number of units : "))
bill = 0

if units > 200:
    bill = (100*5) + ((units - 200)*10)

if units >100 and units <= 200:
     bill = (units - 100)*5


if units <= 100:
    bill = 0


print("Total Electricity Bill = Rs", bill)
# Out:
# enter number of units :  350
# Total Electricity Bill = Rs 2000

# %%
#QUESTION 2 :- Write a program to accept percentage from the user and display
# the grade according to the following criteria:


percentage = input(input("ENTER PERCENTAGE: "))

if percentage >90:
    print("GRADE A")

elif percentage > 80 and percentage <= 90:
    print("GRADE B")

elif percentage >= 60 and percentage <= 80:
    print("GRADE C")

elif percentage:
    print("GRADE D")
# Out:
# ENTER PERCENTAGE 66
# GRADE C

# %%
# QUESTION 3:- Accept the age of 4 people and display the youngest one?

people1 = int(input("enter the name: "))
people2 = int(input("enter the name: "))
people3 = int(input("enter the name: "))
people4 = int(input("enter the name: "))

# NOT SOLVE
# Out:
# enter the name:  people1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 3
#       1 # QUESTION 3:- Accept the age of 4 people and display the youngest one?
# ----> 3 people1 = int(input("enter the name: "))
#       4 people2 = int(input("enter the name: "))
#       5 people3 = int(input("enter the name: "))
#
# ValueError: invalid literal for int() with base 10: 'people1'

# %%
# Question 4:- A company decided to give bonus to employee 


salary = float(input("ENTER SALARY: "))
years = int(input("ENTER YEARS OF SERVICE: "))

if years > 10:
    bonus = salary*0.10

elif years >= 6 and years <10:
    bonus = salary*0.8

elif years <6:
    bonus = salary*0.5


print("NET BONUS AMOUNT = Rs", bonus)
# Out:
# ENTER SALARY:  600000
# ENTER YEARS OF SERVICE:  11
# NET BONUS AMOUNT = Rs 60000.0

# %%
# QUESTION 5:- Accept three numbers from the user and
#display the second largest number?

user2 = int(input("ENTER YOUR NUMBER: "))

if user == three_digit:
    print("second largest number",)


#NOT SOLVE
# Out:
# ENTER YOUR NUMBER:  55
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 6
#       1 # QUESTION 5:- Accept three numbers from the user and
#       2 #display the second largest number?
#       4 user2 = int(input("ENTER YOUR NUMBER: "))
# ----> 6 if user == three_digit:
#       7     print("second largest number",)
#
# NameError: name 'user' is not defined

# %%
# QUESTION 6:-Accept the marked price from the user and calculate
# the Net amount as (Marked Price – Discount) to pay 


marked = float(input("ENTER MARKED PRICE: "))

if marked >10000:
    discount = marked*0.20

elif marked >7000 and marked <=10000:
    discount = marked*0.15

elif marked <= 7000:
    discount = marked*0.10

print("calculate discount amount = Rs", discount)
# Out:
# ENTER MARKED PRICE:  11000
# calculate discount amount = Rs 2200.0

# %%
# QUESTION 7:-Accept the marks of English, Math and Science,
# Social Studies Subject and display the stream allotted

maths = int(input("ENTER YOUR MATHS MARKS: "))
english = int(input("ENTER YOUR ENGLISH MARKS: "))
social_science = int(input("ENTER YOUR SOCIAL_SCIENCE MARKS: "))
science = int(input("ENTER YOUR SCIENCE MARKS: "))


if english > 80 and maths >80 and science >80 and social_science>80:
    print("stream allotted: Science")

elif english > 80 and maths >50 and science >50:
    print("stream allotted: Commerce")

elif english >80 and social_science>80:
    print("stream allotted: Humanities")

else:
    print("Stream:",Alloted)
# Out:
# ENTER YOUR MATHS MARKS:  55
# ENTER YOUR ENGLISH MARKS:  81
# ENTER YOUR SOCIAL_SCIENCE MARKS:  55
# ENTER YOUR SCIENCE MARKS:  55
# stream allotted: Commerce

# %%
# QUESTION 8:- . Write a program to display "Hello" if a number entered
# by user is a multiple of five, otherwise print "Bye"?

user_number = int(input("enter number: "))

if user_number % 5 == 0:
    print("hello")

else:
    print("bye")
# Out:
# enter number:  57
# bye

# %%
# QUESTION 9:-  Write a program to check whether the last digit of a number
# (entered by user) is divisible by 3 or not?

num = int(input("enter number: "))
rem = num%10

if rem %3==0:
    print(True)

else:
    print(False)
# Out:
# enter number:  36
# True

# %%
# QUESTION 10:- Write a program to check whether a number entered
# is three-digit number or not?

num1 = int(input("enter you number: "))

if num1<1000 and num1>99:
    print(True)

else:
    print(False)
# Out:
# enter you number:  666
# True
